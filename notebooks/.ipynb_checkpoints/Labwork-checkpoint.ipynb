# %% [markdown]
# Сначала загрузим данные и посмотрим на колонки

# %%
import pandas as pd

pandas_df = pd.read_csv("./исходные данные/MOCK_DATA (1).csv")
pandas_df.columns
# Out:
# Index(['id', 'customer_first_name', 'customer_last_name', 'customer_age',
#        'customer_email', 'customer_country', 'customer_postal_code',
#        'customer_pet_type', 'customer_pet_name', 'customer_pet_breed',
#        'seller_first_name', 'seller_last_name', 'seller_email',
#        'seller_country', 'seller_postal_code', 'product_name',
#        'product_category', 'product_price', 'product_quantity', 'sale_date',
#        'sale_customer_id', 'sale_seller_id', 'sale_product_id',
#        'sale_quantity', 'sale_total_price', 'store_name', 'store_location',
#        'store_city', 'store_state', 'store_country', 'store_phone',
#        'store_email', 'pet_category', 'product_weight', 'product_color',
#        'product_size', 'product_brand', 'product_material',
#        'product_description', 'product_rating', 'product_reviews',
#        'product_release_date', 'product_expiry_date', 'supplier_name',
#        'supplier_contact', 'supplier_email', 'supplier_phone',
#        'supplier_address', 'supplier_city', 'supplier_country'],
#       dtype='object')

# %% [markdown]
# Из названия колонок можно сразу выделить сущности, которые будут в звезде:
#
# 1. customer
# 2. customer_pet
# 3. seller
# 4. product
# 5. sale
# 6. store
# 7. supplier
#
# Можно заметить, что тут есть колонки, где используется внешний ключ(sale_product_id, например). Получается, что это внешний ключ на строку исходной таблица, а не на конкретную сущность. Из этого можно сделать вывод, что при заполнении снежинки на каждой строке будут либо создаваться новые, либо переписываться старые записи с новым идентификатором строки. Причем во всех файлах MOCK_DATA... id начинается с 1, так что надо будет к id прибавлять количество уже вставленных записей

# %%
for col in filter(lambda x: 'id' in x, pandas_df.columns):
    print(col, len(pandas_df[pandas_df["id"] != pandas_df[col]]))
# Out:
# id 0
# sale_customer_id 0
# sale_seller_id 0
# sale_product_id 0

# %% [markdown]
# Да, все поля с id совпадают с id строки, так что можно вставлять строки как есть

# %%
inserted_rows = 0

# %%
for col in pandas_df.columns:
    unique = pandas_df[col].unique()
    if len(unique) > 200 or 'desc' in col:
        continue
    print(f"{col}: {unique}")
# Out:
# customer_age: [63 26 47 81 72 42 80 77 57 82 31 73 32 30 58 54 46 76 19 61 39 67 45 40
#  27 18 41 38 55 78 62 70 64 36 43 83 33 28 69 51 85 71 37 79 23 35 20 65
#  21 24 66 75 84 49 34 52 59 68 74 22 53 60 44 25 56 50 29 48]
# customer_country: ['France' 'Philippines' 'Madagascar' 'Portugal' 'Russia' 'China' 'Albania'
#  'Venezuela' 'United States' 'Thailand' 'Japan' 'Greece' 'Tanzania' 'Peru'
#  'Indonesia' 'Cuba' 'Poland' 'Brazil' 'Sweden' 'Czech Republic' 'Haiti'
#  'Pakistan' 'Montenegro' 'Macedonia' 'Israel' 'Honduras' 'Colombia'
#  'Kyrgyzstan' 'Zimbabwe' 'Lebanon' 'Argentina' 'Bulgaria' 'Yemen'
#  'Afghanistan' 'Mali' 'Mexico' 'Mauritania'
#  'Democratic Republic of the Congo' 'Mauritius' 'Falkland Islands'
#  'Kazakhstan' 'Ukraine' 'Sierra Leone' 'Spain' 'Dominican Republic'
#  'Palestinian Territory' 'Syria' 'Vietnam' 'Cameroon' 'Angola' 'Egypt'
#  'Costa Rica' 'Serbia' 'Kenya' 'Iran' 'Malaysia' 'Italy' 'Chile' 'Nepal'
#  'Ethiopia' 'Croatia' 'Paraguay' 'Luxembourg' 'South Africa' 'Germany'
#  'French Polynesia' 'Mongolia' 'Finland' 'Somalia' 'Uzbekistan' 'Armenia'
#  'Slovenia' 'Niger' 'Guatemala' 'Morocco' 'Lithuania' 'Nigeria' 'Malawi'
#  'Ireland' 'Bolivia' 'United Arab Emirates' 'Norway' 'Saudi Arabia'
#  'Bangladesh' 'Nicaragua' 'South Korea' 'Moldova' 'Netherlands' 'Panama'
#  'Canada' 'New Zealand' 'North Korea' 'Comoros' 'United Kingdom' 'Estonia'
#  'Gabon' 'Burkina Faso' 'Togo' 'Ecuador' 'Belarus' 'Eritrea' 'Guinea'
#  'Azerbaijan' 'Tunisia' 'Senegal' 'Denmark' 'Ivory Coast' 'Andorra'
#  'American Samoa' 'Jamaica' 'Micronesia' 'Iraq' 'Equatorial Guinea'
#  'Sudan' 'Martinique' 'Swaziland' 'Georgia' 'Laos'
#  'Bosnia and Herzegovina' 'Qatar' 'Botswana' 'Turkmenistan' 'Hong Kong'
#  'Uganda']
# customer_pet_type: ['cat' 'dog' 'bird']
# customer_pet_breed: ['Labrador Retriever' 'Siamese' 'Parakeet']
# seller_country: ['Central African Republic' 'Malaysia' 'Argentina' 'Russia' 'Bulgaria'
#  'Honduras' 'Poland' 'Japan' 'Slovenia' 'Bosnia and Herzegovina'
#  'Indonesia' 'Brazil' 'Croatia' 'China' 'Uganda' 'Italy' 'France'
#  'United Kingdom' 'Vietnam' 'Peru' 'Cameroon' 'Germany' 'Portugal'
#  'Pakistan' 'Canada' 'South Korea' 'Haiti' 'Philippines' 'Colombia'
#  'Palestinian Territory' 'Ukraine' 'Guatemala' 'Afghanistan' 'Norway'
#  'El Salvador' 'Ireland' 'Ghana' 'Czech Republic' 'Nigeria' 'Sweden'
#  'Jordan' 'Nicaragua' 'Kazakhstan' 'Azerbaijan' 'Thailand' 'Tanzania'
#  'Greece' 'Saudi Arabia' 'North Korea' 'Sri Lanka' 'Samoa'
#  'Dominican Republic' 'Democratic Republic of the Congo' 'Venezuela'
#  'Cuba' 'East Timor' 'Georgia' 'Serbia' 'Zambia' 'Paraguay' 'Uzbekistan'
#  'Albania' 'Mexico' 'United States' 'Yemen' 'Montenegro' 'Cambodia'
#  'Armenia' 'Iran' 'Bolivia' 'Belarus' 'Macedonia' 'Botswana' 'Spain'
#  'Latvia' 'Chad' 'Jamaica' 'Burkina Faso' 'Lithuania' 'Laos' 'Chile'
#  'Israel' 'New Zealand' 'Mali' 'Morocco' 'Mauritania' 'Tajikistan'
#  'South Africa' 'Madagascar' 'Lebanon' 'Belgium' 'Luxembourg' 'Moldova'
#  'Qatar' 'Mozambique' 'Malta' 'Senegal' 'Hungary' 'Finland' 'Switzerland'
#  'Turkmenistan' 'Syria' 'Nepal' 'Singapore' 'Suriname' 'Netherlands'
#  'Kosovo' 'Estonia' 'Mongolia' 'Kenya' 'Myanmar' 'Kuwait' 'Costa Rica'
#  'Kyrgyzstan' 'Panama' 'Ethiopia' 'Micronesia' 'Tunisia' 'Gabon' 'Gambia'
#  'Aland Islands']
# product_name: ['Bird Cage' 'Dog Food' 'Cat Toy']
# product_category: ['Food' 'Cage' 'Toy']
# product_quantity: [ 87  88  77  91  35  21  86  63  93  45   5  40  52  60  19  29  44  67
#   47  32  25  48   3 100  18   6  65  76   8  10   4  71  64  49  57  50
#   28  23  61  92  73  14  53  15  31  33  46  13  12  97  68  84  34  90
#   83  27  16   2  51   9  38  80  78  37  39  41  54  26  96  66  69  59
#   82  36  95  75  17  98   1  20  94  42  79  72  89  74  99  56  30  55
#   70  81  85  11  22  43  62   7  58  24]
# sale_quantity: [ 3  4  6  2  7  9  1 10  5  8]
# store_state: ['A8' nan '15' 'WA' 'B7' 'A4' 'K' 'OH' 'B4' 'AB' 'B9' 'JAL' 'TN' 'Z' 'AN'
#  'NLE' 'A7' '97' 'B2' '10' 'SRW' 'SGR' 'LZ' 'MI' 'B5' '03' 'MO' 'TX' 'S'
#  '16' 'A2' 'AZ' 'HB' 'CA' '05' 'MIC' 'O' 'SON' '31' '11' '06' 'FL' 'QC'
#  'NB' 'NU' 'B8' 'CM' 'ENG' 'T' '07' '13' 'W' '12' 'IN' '09' '01' 'ON' 'NY'
#  'KUL' 'I' '1084' 'OAX' 'MQ' 'A3' 'U' 'AC' '18' 'MOR' 'X' 'BY' 'HE' 'NW'
#  'MEX' 'BD']
# store_country: ['Poland' 'China' 'Indonesia' 'Sweden' 'Canada' 'Belarus' 'Lithuania'
#  'South Korea' 'United States' 'Philippines' 'Russia' 'Netherlands' 'Peru'
#  'Ghana' 'Portugal' 'Japan' 'Czech Republic' 'Uruguay' 'Ukraine'
#  'Uzbekistan' 'Honduras' 'Morocco' 'Brazil' 'Colombia' 'Luxembourg'
#  'Yemen' 'Argentina' 'Democratic Republic of the Congo' 'South Africa'
#  'Tanzania' 'Latvia' 'Israel' 'France' 'Vietnam' 'Nigeria' 'Mongolia'
#  'Italy' 'Finland' 'Iran' 'Sri Lanka' 'Djibouti' 'Dominican Republic'
#  'Afghanistan' 'Bulgaria' 'Greece' 'Qatar' 'Cuba' 'Kosovo' 'Madagascar'
#  'Thailand' 'Malaysia' 'Pakistan' 'Armenia' 'Spain' 'Angola' 'Kyrgyzstan'
#  'Nepal' 'Bosnia and Herzegovina' 'Serbia' 'Bhutan' 'Martinique'
#  'New Caledonia' 'Ireland' 'United Kingdom' 'Kazakhstan' 'Ivory Coast'
#  'Kenya' 'Ethiopia' 'North Korea' 'Mexico' 'Germany' 'Taiwan' 'Jordan'
#  'Georgia' 'Egypt' 'Cameroon' 'Tajikistan' 'Equatorial Guinea' 'Nicaragua'
#  'New Zealand' 'Gambia' 'Venezuela' 'Uganda' 'Albania' 'Guatemala' 'Chile'
#  'Paraguay' 'Bangladesh' 'Syria' 'Central African Republic' 'Zambia'
#  'Zimbabwe' 'Mauritius' 'Iraq' 'Gabon' 'Malta' 'Botswana'
#  'Palestinian Territory' 'Cyprus' 'Benin' 'Sudan' 'Costa Rica' 'Croatia'
#  'Saint Vincent and the Grenadines' 'Slovenia' 'Laos' 'Burundi' 'Lebanon'
#  'Norway' 'Jamaica' 'Macedonia' 'Chad' 'Australia' 'Niger' 'East Timor'
#  'Seychelles' 'Samoa' 'Hungary' 'Saudi Arabia' 'Myanmar' 'Panama'
#  'Grenada']
# pet_category: ['Fish' 'Dogs' 'Reptiles' 'Cats' 'Birds']
# product_color: ['Red' 'Pink' 'Mauv' 'Indigo' 'Maroon' 'Turquoise' 'Yellow' 'Purple'
#  'Violet' 'Blue' 'Goldenrod' 'Khaki' 'Teal' 'Fuscia' 'Green' 'Crimson'
#  'Orange' 'Aquamarine' 'Puce']
# product_size: ['Large' 'Medium' 'Small']
# product_material: ['Stone' 'Vinyl' 'Brass' 'Plexiglass' 'Plastic' 'Glass' 'Wood' 'Steel'
#  'Granite' 'Aluminum' 'Rubber']
# product_rating: [3.6 2.1 1.5 2.4 1.4 2.6 1.2 1.6 3.5 2.3 3.7 2.5 3.1 3.2 4.  4.8 5.  4.5
#  3.9 4.2 2.8 2.2 2.9 1.8 2.7 4.1 1.9 2.  4.4 1.  3.3 3.4 3.  4.3 4.9 4.7
#  1.7 1.1 3.8 1.3 4.6]
# supplier_country: ['Russia' 'Sweden' 'Portugal' 'China' 'Poland' 'Brazil' 'Uganda'
#  'Colombia' 'Zimbabwe' 'Philippines' 'Czech Republic' 'Kenya' 'Thailand'
#  'Indonesia' 'Bulgaria' 'Finland' 'Canada' 'Bangladesh' 'Tunisia'
#  'Nigeria' 'Dominican Republic' 'Comoros' 'Norway' 'Mongolia'
#  'United States' 'Ukraine' 'Ireland' 'Netherlands' 'Japan' 'Greece'
#  'France' 'Tanzania' 'Peru' 'Panama' 'Sierra Leone' 'Burkina Faso'
#  'Palestinian Territory' 'Macedonia' 'Argentina' 'Mexico' 'South Africa'
#  'Venezuela' 'Senegal' 'Taiwan' 'Azerbaijan' 'Pakistan' 'Mozambique'
#  'Vietnam' 'Uzbekistan' 'Serbia' 'Lithuania' 'Nicaragua' 'New Zealand'
#  'Belarus' 'Haiti' 'Sri Lanka' 'Tajikistan' 'Spain' 'Iran' 'Costa Rica'
#  'Cuba' 'Syria' 'Honduras' 'Libya' 'Bosnia and Herzegovina' 'Angola'
#  'Mali' 'North Korea' 'Cameroon' 'Guinea-Bissau' 'Namibia' 'Vanuatu'
#  'Kyrgyzstan' 'Jordan' 'Israel' 'Albania' 'Saint Kitts and Nevis'
#  'United Kingdom' 'Croatia' 'Bahamas' 'Afghanistan' 'Morocco' 'Ghana'
#  'Somalia' 'Ivory Coast' 'Maldives' 'Liberia' 'Ecuador' 'Germany' 'Bhutan'
#  'Paraguay' 'Cambodia' 'Mayotte' 'Luxembourg' 'French Polynesia' 'Yemen'
#  'Malta' 'Malaysia' 'Guinea' 'Burundi' 'Saudi Arabia' 'Ethiopia'
#  'Central African Republic' 'Niger' 'Montenegro' 'Armenia' 'Australia'
#  'Guatemala' 'Georgia' 'Gambia' 'Egypt' 'El Salvador' 'Madagascar' 'Nepal'
#  'South Korea' 'Romania' 'Moldova' 'Jamaica' 'Latvia' 'Sudan' 'Italy'
#  'Kazakhstan' 'Estonia' 'Dominica' 'Reunion' 'Zambia'
#  'Democratic Republic of the Congo' 'Palau']

# %%
pd.to_datetime(pandas_df['product_expiry_date'].head())
# Out:
# 0   2026-02-28
# 1   2029-09-11
# 2   2024-01-05
# 3   2025-06-03
# 4   2030-07-10
# Name: product_expiry_date, dtype: datetime64[ns]

# %%
pd.DataFrame({'a': pd.Series(dtype='datetime64[ns]'), 'b': pd.Series(dtype="int"), "c": pd.Series(dtype="float"), "d" : pd.Series(dtype="str")}).dtypes
# Out:
# a    datetime64[ns]
# b             int64
# c           float64
# d            object
# dtype: object

# %% [markdown]
# Терерь я опишу функцию, которая будет разделать большой фрейм на несколько меньших

# %%
inserted_rows = 0
customer = pd.DataFrame({
    "customer_first_name": pd.Series(dtype="str"),
    'customer_last_name': pd.Series(dtype="str"),
    'customer_age': pd.Series(dtype="int"),
    'customer_email': pd.Series(dtype="str"),
    'customer_country': pd.Series(dtype="str"),
    'customer_postal_code' : pd.Series(dtype="str"),
    'customer_pet_id' : pd.Series(dtype="int")
})
pet = pd.DataFrame({
    "customer_pet_type": pd.Series(dtype="str"),
    "customer_pet_name": pd.Series(dtype="str"),
    "customer_pet_breed": pd.Series(dtype="str"),
})
seller = pd.DataFrame({
    'seller_first_name': pd.Series(dtype="str"),
    'seller_last_name': pd.Series(dtype="str"),
    'seller_email': pd.Series(dtype="str"),
    'seller_country': pd.Series(dtype="str"),
    'seller_postal_code': pd.Series(dtype="str")
})
product = pd.DataFrame({
    'product_name': pd.Series(dtype="str"),
    'product_category': pd.Series(dtype="str"),
    'product_price': pd.Series(dtype="float"),
    'product_quantity': pd.Series(dtype="float"),
    'product_weight': pd.Series(dtype="float"),
    'product_color': pd.Series(dtype="str"),
    'product_size': pd.Series(dtype="str"),
    'product_brand': pd.Series(dtype="str"),
    'product_material': pd.Series(dtype="str"),
    'product_description': pd.Series(dtype="str"),
    'product_rating': pd.Series(dtype="float"),
    'product_reviews': pd.Series(dtype="int"),
    'product_release_date': pd.Series(dtype="datetime64[ns]"),
    'product_expiry_date': pd.Series(dtype="datetime64[ns]"),
    'pet_category' : pd.Series(dtype="str")
})
sale = pd.DataFrame({
    'sale_date': pd.Series(dtype="datetime64[ns]"),
    'sale_customer_id': pd.Series(dtype="int"),
    'sale_seller_id': pd.Series(dtype="int"),
    'sale_store_id': pd.Series(dtype="int"),
    'sale_supplier_id': pd.Series(dtype="int"),
    'sale_product_id': pd.Series(dtype="int"),
    'sale_quantity': pd.Series(dtype="float"),
    'sale_total_price': pd.Series(dtype="float")
})
store = pd.DataFrame({
    'store_name': pd.Series(dtype="str"),
    'store_location': pd.Series(dtype="str"),
    'store_city': pd.Series(dtype="str"),
    'store_state': pd.Series(dtype="str"),
    'store_country': pd.Series(dtype="str"),
    'store_phone': pd.Series(dtype="str"),
    'store_email': pd.Series(dtype="str"),
})

supplier = pd.DataFrame({
    'supplier_name': pd.Series(dtype="str"),
    'supplier_contact': pd.Series(dtype="str"),
    'supplier_email': pd.Series(dtype="str"),
    'supplier_phone': pd.Series(dtype="str"),
    'supplier_address': pd.Series(dtype="str"),
    'supplier_city': pd.Series(dtype="str"),
    'supplier_country': pd.Series(dtype="str")
})

# %%
def split_raw_df(df):
    global customer, pet, seller, product, sale, store, supplier, inserted_rows
    
    customer = pd.concat([df, customer], join='inner', ignore_index='true')
    customer.index += 1
    customer["pet_id"] = customer.index
    pet = pd.concat([df, pet], join='inner', ignore_index='true')
    pet.index += 1
    seller = pd.concat([df, seller], join='inner', ignore_index='true')
    seller.index += 1
    product = pd.concat([df, product], join='inner', ignore_index='true')
    product.index += 1
    sale = pd.concat([df, sale], join='inner', ignore_index='true')
    sale.index += 1
    sale["sale_store_id"] = sale.index
    sale["sale_supplier_id"] = sale.index
    store = pd.concat([df, store], join='inner', ignore_index='true')
    store.index += 1
    supplier = pd.concat([df, supplier], join='inner', ignore_index='true')
    supplier.index += 1


    for col in ['sale_customer_id','sale_seller_id','sale_product_id']:
    	sale[col] += inserted_rows

    inserted_rows += len(df)

# %%
split_raw_df(pandas_df)

# %%
customer.columns = [ 'first_name', 'last_name', 'age', 'email', 'country', 'postal_code' , 'pet_id' ]
pet.columns = [ "type", "name", "breed" ]
seller.columns = [ 'first_name', 'last_name', 'email', 'country', 'postal_code' ]
product.columns = ['name', 'category', 'price', 'quantity', 'pet_category', 'weight', 'color', 'size', 'brand', 'material', 'description', 'rating', 'reviews', 'release_date', 'expiry_date' ]
sale.columns = [ 'date', 'customer_id', 'seller_id', 'store_id', 'supplier_id','product_id', 'quantity', 'total_price' ]
store.columns = [ 'name', 'location', 'city', 'state', 'country', 'phone', 'email' ]
supplier.columns = [ 'name', 'contact', 'email', 'phone', 'address', 'city', 'country' ]

# %%
product["expiry_date"] = product["expiry_date"].astype("datetime64[ns]")
product["release_date"] = product["release_date"].astype("datetime64[ns]")
sale["date"] = sale["date"].astype("datetime64[ns]")

# %%
customer.head()
# Out:
#   first_name     last_name  age                     email      country  \
# 1      Conni        Leydon   63        lswait0@amazon.com       France
# 2       Alec  Chamberlayne   26         cwalsh1@state.gov  Philippines
# 3    Vaughan       Shapiro   47        jelnough2@xing.com   Madagascar
# 4       Bank         Audas   81  lscay3@howstuffworks.com     Portugal
# 5      Anthe        Pletts   72    ctoll4@miibeian.gov.cn       Russia
#
#    postal_code  pet_id
# 1  77404 CEDEX       1
# 2         9401       2
# 3          NaN       3
# 4     2860-010       4
# 5       628389       5

# %%
sale.head()
# Out:
#         date  customer_id  seller_id  store_id  supplier_id  product_id  \
# 1 2021-02-27            1          1         1          3.0       83.32
# 2 2021-02-27            2          2         2          4.0      384.20
# 3 2021-11-30            3          3         3          6.0       11.58
# 4 2021-10-24            4          4         4          2.0      273.35
# 5 2021-06-27            5          5         5          2.0      305.87
#
#    quantity  total_price
# 1         1            1
# 2         2            2
# 3         3            3
# 4         4            4
# 5         5            5

# %% [markdown]
# Теперь можно подключить spark и сделать экспорт данных в postgres. Я заметил нюанс, который скорее всего связан с jupyter notebook: когда создается переменная spark ниже, то потом при пересоздании он использует старую версию переменной, т.е. если в конфиге указать только jar файл для postgresql, а в другой ячейке для postgresql и clickhouse, то при подключении к clickhouse будет ошибка, типа jar файл не найден
#
# Поэтому сразу подключу оба jar файла

# %% [markdown]
# Можно заметить, что для работы spark нужно создавать сессии, так что имеет смысл выделить создание и закрытие сессии в отдельную функцию-декоратор

# %%
from functools import wraps
from pyspark.sql import SparkSession

def spark_session(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        spark = SparkSession.builder \
            .appName("Spark SQL with PostgreSQL and ClickHouse") \
            .config("spark.jars", "postgresql-42.6.0.jar,clickhouse-jdbc-0.8.5-all.jar")\
            .getOrCreate()
        result = func(*args, spark=spark, **kwargs)
        spark.stop()
        return result
    return wrapper

dbData = {
    "postgresql" :  ("jdbc:postgresql://postgres:5432/spark_db", {
        "user": "spark_user",
        "password": "spark_password",
        "driver": "org.postgresql.Driver"
    }),
    "clickhouse" : ("jdbc:clickhouse://clickhouse:8123/default", {
        "driver": "com.clickhouse.jdbc.ClickHouseDriver",
        "user": "custom_user",
        "password": "custom_password"
    })
}

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum

@spark_session
def view_preview(spark):
    data = [
    	("pets", spark.createDataFrame(pet)),
    	("customers", spark.createDataFrame(customer)),
    	("sellers", spark.createDataFrame(seller)),
    	("products", spark.createDataFrame(product)),
    	("stores", spark.createDataFrame(store)),
    	("suppliers", spark.createDataFrame(supplier)),
        ("sales", spark.createDataFrame(sale))
    ]
    data[6][1].createOrReplaceTempView("sales")
    sqlDf = spark.sql("select * from sales limit 10;")
    sqlDf.show()
view_preview()
# Out:
# +-------------------+-----------+---------+--------+-----------+----------+--------+-----------+
# |               date|customer_id|seller_id|store_id|supplier_id|product_id|quantity|total_price|
# +-------------------+-----------+---------+--------+-----------+----------+--------+-----------+
# |2021-02-27 00:00:00|          1|        1|       1|        3.0|     83.32|       1|          1|
# |2021-02-27 00:00:00|          2|        2|       2|        4.0|     384.2|       2|          2|
# |2021-11-30 00:00:00|          3|        3|       3|        6.0|     11.58|       3|          3|
# |2021-10-24 00:00:00|          4|        4|       4|        2.0|    273.35|       4|          4|
# |2021-06-27 00:00:00|          5|        5|       5|        2.0|    305.87|       5|          5|
# |2021-06-25 00:00:00|          6|        6|       6|        3.0|    454.33|       6|          6|
# |2021-12-19 00:00:00|          7|        7|       7|        7.0|    462.47|       7|          7|
# |2021-01-04 00:00:00|          8|        8|       8|        9.0|     17.17|       8|          8|
# |2021-12-28 00:00:00|          9|        9|       9|        1.0|    417.48|       9|          9|
# |2021-04-05 00:00:00|         10|       10|      10|        7.0|    483.95|      10|         10|
# +-------------------+-----------+---------+--------+-----------+----------+--------+-----------+

# %% [markdown]
# Экспорт данных в postgresql

# %%
@spark_session
def export_to_postgresql(spark):
    data = [
    	("pets", spark.createDataFrame(pet)),
    	("customers", spark.createDataFrame(customer)),
    	("sellers", spark.createDataFrame(seller)),
    	("products", spark.createDataFrame(product)),
    	("stores", spark.createDataFrame(store)),
    	("suppliers", spark.createDataFrame(supplier)),
        ("sales", spark.createDataFrame(sale))
    ]
    pg_url, pg_props =  dbData["postgresql"]
    
    for table, df in data:
        df.write\
        .jdbc(url=pg_url, table=table, mode="append", properties=pg_props)

export_to_postgresql()

# %% [markdown]
# Теперь будем собирать статистику и делать витрины

# %% [markdown]
# Витрина на продукты

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row
from pyspark.sql.functions import create_map, array_agg, array, map_from_entries, struct

@spark_session
def products_report(spark):
    pg_url, pg_props =  dbData["postgresql"]
    
    products = spark.read.jdbc(url=pg_url, table="products", properties=pg_props)
    sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
    
    sales.createOrReplaceTempView("sales")
    products.createOrReplaceTempView("products")
    
    most_salling_products = spark.sql("""
    select array_agg(t1.name) as names
    from (
    select t1.name as name, count(t2.product_id) as sales
    from
        products as t1
    inner join 
        sales as t2
    on t1.id = t2.product_id
    group by t1.name
    order by sales desc
    limit 10) as t1;
    """)
    
    revenue_per_category = spark.sql(
    """
    select struct(t1.category, sum(price)) as data
        from 
        products as t1
    inner join 
        sales as t2
    on t1.id = t2.product_id
    group by t1.category;
    """)
    
    mean_mark_and_reviews_per_product = spark.sql("""
    select
        name,
        avg(rating) as mean_avg,
        avg(reviews) as mean_reviews
    from products
    group by name;
    """)
    
    print("Самые продаваемые товары")
    display(most_salling_products.toPandas())
    
    print("Выручка по категориям")
    display(revenue_per_category.toPandas())
    
    print("Средняя оценка и количество комментариев для каждого предмета(первые 5)")
    display(mean_mark_and_reviews_per_product.toPandas().head())
    
    schema = StructType([
        StructField("mostRelevantProducts", ArrayType(StringType()), False),
        StructField("categoryRevenue", MapType(StringType(), FloatType()), True),
        StructField("ratePerProduct", MapType(StringType(), FloatType()), True),
        StructField("commentPerProduct", MapType(StringType(), FloatType()), True),
    ])
    
    most_relevant = most_salling_products
    category_revenue = revenue_per_category.select(map_from_entries(array_agg("data")).alias("data"))
    marks_per_product = mean_mark_and_reviews_per_product.select(map_from_entries(array_agg(struct("name", "mean_avg"))).alias("data"))
    reviews_per_product = mean_mark_and_reviews_per_product.select(map_from_entries(array_agg(struct("name","mean_reviews"))).alias("data"))
    
    ch_products_df = spark.createDataFrame(data=[
        (most_relevant.first()["names"],
         category_revenue.first()["data"],
         marks_per_product.first()["data"],
         reviews_per_product.first()["data"])
    ], schema=schema)
    
    ch_products_df2 = spark.createDataFrame(data=[
        Row(data=ch_products_df.toJSON().first())
    ])
    
    ch_url, ch_props =  dbData["clickhouse"]
    
    ch_products_df2.write.jdbc(url=ch_url, table="products", mode="append", properties=ch_props)

products_report()
# Out:
# Самые продаваемые товары
#                             names
# 0  [Bird Cage, Cat Toy, Dog Food]
# Выручка по категориям
#                          data
# 0  (Cage, 17162.959999999995)
# 1   (Food, 15043.65000000001)
# 2    (Toy, 17018.78999999997)
# Средняя оценка и количество комментариев для каждого предмета(первые 5)
#         name  mean_avg  mean_reviews
# 0  Bird Cage  2.996979    484.670695
# 1   Dog Food  3.092394    500.453521
# 2    Cat Toy  3.086624    499.149682

# %% [markdown]
# Витрина на продажи по покупателям

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row, IntegerType
from pyspark.sql.functions import create_map, array_agg, array, map_from_entries, struct

@spark_session
def customers_report(spark):
    pg_url, pg_props =  dbData["postgresql"]
    
    customers = spark.read.jdbc(url=pg_url, table="customers", properties=pg_props)
    sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
    
    sales.createOrReplaceTempView("sales")
    customers.createOrReplaceTempView("customers")
    
    most_relevant_customers = spark.sql("""
    select array_agg(t1.name) as names
    from (
    select t1.first_name as name, count(t1.id) as sales
    from
        customers as t1
    inner join 
        sales as t2
    on t1.id = t2.customer_id
    group by t1.first_name
    order by sales desc
    limit 10) as t1;
    """)
    
    customer_country_stratification = spark.sql(
    """
		select array_agg(struct(t1.*)) as entries from (
		select t1.country as country, count(t1.id) as sales
			from 
					customers as t1
			inner join 
					sales as t2
			on t1.id = t2.customer_id
			group by t1.country
		) as t1;
    """)
    
    mean_order_cost_per_customer = spark.sql("""
		select array_agg(struct(t1.*)) as entries
    from (
		select
        t1.first_name as name,
        avg(t2.total_price) as mean_order_cost
		from 
				customers as t1
		inner join 
				sales as t2
    group by t1.first_name
		) as t1;
    """)
    
    print("Самые покупающие покупатели")
    display(most_relevant_customers.toPandas())
    
    print("Распределение продаж по странам")
    display(customer_country_stratification.toPandas())
    
    print("Средняя стоимость покупок на пользователя(первые 5)")
    display(mean_order_cost_per_customer.toPandas().head())
    
    schema = StructType([
        StructField("mostRelevantCustomers", ArrayType(StringType()), False),
        StructField("customerCountryStratification", MapType(StringType(), IntegerType()), False),
        StructField("meanOrderCostPerCustomer", MapType(StringType(), FloatType()), False),
    ])
    
    most_relevant_customers = most_relevant_customers.first()["names"]
    customer_country_stratification = customer_country_stratification.select(map_from_entries("entries").alias("data")).first()["data"]
    mean_order_cost_per_customer = mean_order_cost_per_customer.select(map_from_entries("entries").alias("data")).first()["data"]
    
    ch_products_df = spark.createDataFrame(data=[
        (most_relevant_customers,
         customer_country_stratification,
         mean_order_cost_per_customer)
    ], schema=schema)
    
    ch_products_df2 = spark.createDataFrame(data=[
        Row(data=ch_products_df.toJSON().first())
    ])
    
    ch_url, ch_props =  dbData["clickhouse"]
    
    ch_products_df2.write.jdbc(url=ch_url, table="sales_per_customers", mode="append", properties=ch_props)

customers_report()
# Out:
# Самые покупающие покупатели
#                                                names
# 0  [Georas, Vale, Edee, Rubi, Tate, Dorian, Nonah...
# Распределение продаж по странам
#                                              entries
# 0  [(Russia, 74), (Paraguay, 3), (Yemen, 3), (Sen...
# Средняя стоимость покупок на пользователя(первые 5)
#                                              entries
# 0  [(Sandi, 500.5), (Reta, 500.5), (Donielle, 500...

# %% [markdown]
# Распределение продаж по времени

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row, IntegerType, Tuple
from pyspark.sql.functions import create_map, array_agg, array, map_from_entries, struct, col

@spark_session
def sales_per_time_report(spark):
    pg_url, pg_props =  dbData["postgresql"]
    
    sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
    
    sales.createOrReplaceTempView("sales")
    
    year_and_month_trands = spark.sql("""
		select cast(t1.year_month as varchar(20)) as year_month, t1.sales - lag(t1.sales) over (order by t1.year_month) as trand
		from 
          (select
              t1.year_month,
              count(*) as sales
            from (
        		select 
        			date_trunc('month', date) as year_month
        		from sales
    		) as t1
            group by t1.year_month
            order by t1.year_month) as t1;
    """)
    
    period_revenue_comparison = spark.sql(
    """
		select 
          t1.period,
          sum(t1.total_price) as overall_price
        from (
        select 
			date_trunc('month', date) as period,
            total_price
		from sales
        ) as t1
        group by t1.period
        order by t1.period;
    """)
    
    mean_order_size_per_month = spark.sql("""
			select
				t1.month as month,
				avg(t1.order_size) as mean_order_size
			from (
				select
					extract (month from date) as month,
					quantity as order_size
				from sales
			) as t1
            group by t1.month;
    """)
    
    print("Тренды по годам и месяцам")
    display(year_and_month_trands.toPandas())
    
    print("Сравнение выручки по периодам(месяцам)")
    display(period_revenue_comparison.toPandas())
    
    print("Средний размер покупок за месяц")
    display(mean_order_size_per_month.toPandas().head())
    
    schema = StructType([
        StructField("yearAndMonthTrands", MapType(StringType(), FloatType()), False),
        StructField("periodsRevenueComparison", MapType(StringType(), FloatType()), False),
        StructField("meanOrderSizePerMonth", MapType(StringType(), FloatType()), False),
    ])
    
    
    ch_products_df = spark.createDataFrame(data=[
        (year_and_month_trands.select(map_from_entries(array_agg(struct("year_month", col("trand").cast("float")))).alias("data")).first()["data"],
         period_revenue_comparison.select(map_from_entries(array_agg(struct("period", "overall_price"))).alias("data")).first()["data"],
         mean_order_size_per_month.select(map_from_entries(array_agg(struct("month", "mean_order_size"))).alias("data")).first()["data"])
    ], schema=schema)
    
    ch_products_df2 = spark.createDataFrame(data=[
        Row(data=ch_products_df.toJSON().first())
    ])
    
    ch_url, ch_props =  dbData["clickhouse"]
    
    ch_products_df2.write.jdbc(url=ch_url, table="sales_per_times", mode="append", properties=ch_props)

sales_per_time_report()
# Out:
# Тренды по годам и месяцам
#              year_month  trand
# 0   2021-01-01 00:00:00    NaN
# 1   2021-02-01 00:00:00  -21.0
# 2   2021-03-01 00:00:00    3.0
# 3   2021-04-01 00:00:00   13.0
# 4   2021-05-01 00:00:00   11.0
# 5   2021-06-01 00:00:00  -22.0
# 6   2021-07-01 00:00:00    2.0
# 7   2021-08-01 00:00:00   16.0
# 8   2021-09-01 00:00:00   -5.0
# 9   2021-10-01 00:00:00   -1.0
# 10  2021-11-01 00:00:00    3.0
# 11  2021-12-01 00:00:00  -17.0
# Сравнение выручки по периодам(месяцам)
#        period  overall_price
# 0  2021-01-01        42266.0
# 1  2021-02-01        33184.0
# 2  2021-03-01        35632.0
# 3  2021-04-01        44810.0
# 4  2021-05-01        48698.0
# 5  2021-06-01        36891.0
# 6  2021-07-01        44004.0
# 7  2021-08-01        50436.0
# 8  2021-09-01        42229.0
# 9  2021-10-01        42712.0
# 10 2021-11-01        41265.0
# 11 2021-12-01        38373.0
# Средний размер покупок за месяц
#    month  mean_order_size
# 0     12       525.657534
# 1      1       464.461538
# 2      6       491.880000
# 3      3       488.109589
# 4      5       502.041237

# %% [markdown]
# Распределение продаж по магазинам

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row, IntegerType, Tuple
from pyspark.sql.functions import create_map, array_agg, array, map_from_entries, struct, col

@spark_session
def sales_per_stores_report(spark):
		pg_url, pg_props =	dbData["postgresql"]
		
		sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
		stores = spark.read.jdbc(url=pg_url, table="stores", properties=pg_props)
		
		sales.createOrReplaceTempView("sales")
		stores.createOrReplaceTempView("stores")
		
		most_relevant_stores = spark.sql("""
		select t1.name, count(*) as sales
		from 
			sales as t2
		inner join
			stores as t1
		on t2.store_id = t1.id
		group by t1.name
        order by sales desc
		""")
		
		state_country_sales_distribution = spark.sql(
		"""
		select concat(t1.country, ',', t1.state) as location, count(*) as sales
		from 
			sales as t2
		inner join
			stores as t1
		on t2.store_id = t1.id
		group by t1.country, t1.state
		""")
		
		mean_order_cost_per_store = spark.sql("""
		select t1.name, avg(t2.total_price) as mean_order_cost
        from
			sales as t2
		inner join
			stores as t1
		group by t1.name;
		""")
		
		print("Лучшие магазины")
		display(most_relevant_stores.toPandas())
		
		print("Распределение по странам и городам")
		display(state_country_sales_distribution.toPandas())
		
		print("Средняя стоимость заказа в магазине")
		display(mean_order_cost_per_store.toPandas())
		
		schema = StructType([
				StructField("mostRelevantStores", ArrayType(StringType()), False),
				StructField("stateCountrySalesDistribution", MapType(StringType(), IntegerType()), False),
				StructField("meanOrderCostPerStore", MapType(StringType(), FloatType()), False),
		])
		
		
		ch_products_df = spark.createDataFrame(data=[
				(most_relevant_stores.select(array_agg("name").alias("data")).first()["data"],
				 state_country_sales_distribution.select(map_from_entries(array_agg(struct("location", "sales"))).alias("data")).first()["data"],
				 mean_order_cost_per_store.select(map_from_entries(array_agg(struct("name", "mean_order_cost"))).alias("data")).first()["data"])
		], schema=schema)
		
		ch_products_df2 = spark.createDataFrame(data=[
				Row(data=ch_products_df.toJSON().first())
		])
		
		ch_url, ch_props =	dbData["clickhouse"]
		
		ch_products_df2.write.jdbc(url=ch_url, table="sales_per_stores", mode="append", properties=ch_props)

sales_per_stores_report()
# Out:
# Лучшие магазины
#               name  sales
# 0         Livetube     10
# 1          Rhycero      8
# 2           Trunyx      8
# 3           Meevee      8
# 4          Dynabox      8
# ..             ...    ...
# 354        Centizu      1
# 355         Zoozzy      1
# 356        Voolith      1
# 357  Thoughtbridge      1
# 358         Rhyzio      1
#
# [359 rows x 2 columns]
# Распределение по странам и городам
#                          location  sales
# 0                     Georgia,NaN      1
# 1                  Afghanistan,MI      1
# 2                  Kyrgyzstan,NaN      1
# 3                       China,SRW      1
# 4                        China,03      3
# ..                            ...    ...
# 244                     Russia,09      1
# 245                      China,TN      1
# 246                  Indonesia,CM      1
# 247  Central African Republic,NaN      1
# 248                Philippines,12      2
#
# [249 rows x 2 columns]
# Средняя стоимость заказа в магазине
#               name  mean_order_cost
# 0          Jetwire            500.5
# 1         Jaxworks            500.5
# 2        Reallinks            500.5
# 3      Brainlounge            500.5
# 4         Snaptags            500.5
# ..             ...              ...
# 354         Skyble            500.5
# 355  Thoughtbridge            500.5
# 356          Yamia            500.5
# 357      Edgepulse            500.5
# 358         Rhyzio            500.5
#
# [359 rows x 2 columns]

# %% [markdown]
# Распреление продаж по диллерам

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row, IntegerType, Tuple
from pyspark.sql.functions import create_map, array_agg, array, map_from_entries, struct, col

@spark_session
def sales_per_suppliers_report(spark):
		pg_url, pg_props =	dbData["postgresql"]
		
		sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
		suppliers = spark.read.jdbc(url=pg_url, table="suppliers", properties=pg_props)
		products = spark.read.jdbc(url=pg_url, table="products", properties=pg_props)
		
		sales.createOrReplaceTempView("sales")
		suppliers.createOrReplaceTempView("suppliers")
		products.createOrReplaceTempView("products")
		
		most_relevant_suppliers = spark.sql("""
		select t1.name, count(*) as sales
		from 
			sales as t2
		inner join
			suppliers as t1
		on t2.supplier_id = t1.id
		group by t1.name
		order by sales desc
		""")
		
		mean_product_cost_per_supplier = spark.sql(
		"""
		select t3.supplier_name, avg(t4.price) as mean_product_price
		from 
			(
			select t1.name as supplier_name, t2.* from
			sales as t2
		inner join
			suppliers as t1
		on t2.supplier_id = t1.id
			) as t3
		inner join
			products as t4
		on t3.product_id = t4.id
		group by t3.supplier_name;
		""")
		
		supplier_sales_per_country_distribution = spark.sql("""
		select t1.country, count(*) as sales
		from
			sales as t2
		inner join
			suppliers as t1
		on t2.supplier_id = t1.id
		group by t1.country;
		""")
		
		print("Самые крутые диллеры")
		display(most_relevant_suppliers.toPandas())
		
		print("Средняя цена товара на диллера")
		display(mean_product_cost_per_supplier.toPandas())
		
		print("Распределение диллеров по странам")
		display(supplier_sales_per_country_distribution.toPandas().head())
		
		schema = StructType([
				StructField("mostRelevantSuppliers", ArrayType(StringType()), False),
				StructField("meanProductCostPerSupplier", MapType(StringType(), FloatType()), False),
				StructField("supplierSalesPerCountryDistribution", MapType(StringType(), IntegerType()), False),
		])
		
		
		ch_products_df = spark.createDataFrame(data=[
				(most_relevant_suppliers.select(array_agg("name").alias("data")).first()["data"],
				 mean_product_cost_per_supplier.select(map_from_entries(array_agg(struct("supplier_name", "mean_product_price"))).alias("data")).first()["data"],
				 supplier_sales_per_country_distribution.select(map_from_entries(array_agg(struct("country", "sales"))).alias("data")).first()["data"])
		], schema=schema)
		
		ch_products_df2 = spark.createDataFrame(data=[
				Row(data=ch_products_df.toJSON().first())
		])
		
		ch_url, ch_props =	dbData["clickhouse"]
		
		ch_products_df2.write.jdbc(url=ch_url, table="sales_per_suppliers", mode="append", properties=ch_props)

sales_per_suppliers_report()
# Out:
# Самые крутые диллеры
#         name  sales
# 0   Devpoint    109
# 1   Digitube    107
# 2     Twimbo    104
# 3  Realpoint    104
# 4    Rhycero    102
# 5    Myworks     97
# 6     Voolia     95
# 7  Jaxnation     94
# 8    Cogibox     94
# 9   Feedfire     94
# Средняя цена товара на диллера
#   supplier_name  mean_product_price
# 0       Rhycero           49.571373
# 1      Devpoint           48.520000
# 2       Myworks           50.751546
# 3      Digitube           44.299065
# 4        Twimbo           48.845865
# 5        Voolia           46.604421
# 6     Realpoint           48.234038
# 7     Jaxnation           45.040106
# 8       Cogibox           57.687128
# 9      Feedfire           53.589894
# Распределение диллеров по странам
#                  country  sales
# 0                  China    303
# 1  Saint Kitts and Nevis    109
# 2              Indonesia    285
# 3                 Brazil    104
# 4                  Japan    104

# %% [markdown]
# Распределение качества товаров

# %%
from pyspark.sql.types import StructType, StructField, StringType, MapType, FloatType, ArrayType, Row, IntegerType, Tuple
from pyspark.sql.functions import create_map, array_agg, array, create_map, struct, corr

@spark_session
def quantity_of_products_report(spark):
		pg_url, pg_props =	dbData["postgresql"]
		
		sales = spark.read.jdbc(url=pg_url, table="sales", properties=pg_props)
		products = spark.read.jdbc(url=pg_url, table="products", properties=pg_props)
		
		sales.createOrReplaceTempView("sales")
		products.createOrReplaceTempView("products")
		
		products_highest_rate = spark.sql("""
		select name as key, rating as value
		from (
            select name, rating
            from products
            order by rating desc
            limit 10
        );
		""")
		
		product_lowest_rate = spark.sql("""
		select name as key, rating as value
		from (
            select name, rating
            from products
            order by rating
            limit 10
        );
		""")
		
		rate_and_sales_count_correlation = spark.sql("""
		select rating, count(*) as sales
		from
			sales as t2
		inner join
			products as t1
		on t2.product_id = t1.id
		group by t1.rating;
		""")

		products_with_biggest_coments_quantity = spark.sql("""
		select name as key, reviews as value
		from (
            select name, reviews
            from products
            order by reviews desc
            limit 25
        );
		""")
		
		print("Самые крутые товары")
		display(products_highest_rate.toPandas())
		
		print("Самые плохие товары")
		display(product_lowest_rate.toPandas())
		
		print("Корреляция продаж и рейтинга(сырые данные)")
		display(rate_and_sales_count_correlation.toPandas().head())

		print("Товары с наибольшим количеством комментариев")
		display(products_with_biggest_coments_quantity.toPandas())

		
		schema = StructType([
				StructField("productsHighestRate", ArrayType(MapType(StringType(), FloatType())), False),
				StructField("productsLowestRate", ArrayType(MapType(StringType(), FloatType())), False),
				StructField("rateAndSalesCountCorrelation", FloatType(), False),
				StructField("productsWithBigCommentsQuantity", ArrayType(MapType(StringType(), IntegerType())), False)
            ])
		
		ch_product_df = spark.createDataFrame(data=[
				(products_highest_rate.select(array_agg(create_map("key", "value")).alias("data")).first()["data"],
				 product_lowest_rate.select(array_agg(create_map("key", "value")).alias("data")).first()["data"],
				 rate_and_sales_count_correlation.agg(corr("rating", "sales").alias("data")).first()["data"],
                 products_with_biggest_coments_quantity.select(array_agg(create_map("key", "value")).alias("data")).first()["data"])
		], schema=schema)
		
		ch_product_df2 = spark.createDataFrame(data=[
				Row(data=ch_product_df.toJSON().first())
		])
		
		ch_url, ch_props =	dbData["clickhouse"]
		
		ch_product_df2.write.jdbc(url=ch_url, table="quality_of_products", mode="append", properties=ch_props)

quantity_of_products_report()
# Out:
# Самые крутые товары
#          key  value
# 0  Bird Cage    5.0
# 1   Dog Food    5.0
# 2    Cat Toy    5.0
# 3   Dog Food    5.0
# 4   Dog Food    5.0
# 5   Dog Food    5.0
# 6   Dog Food    5.0
# 7    Cat Toy    5.0
# 8    Cat Toy    5.0
# 9   Dog Food    5.0
# Самые плохие товары
#          key  value
# 0   Dog Food    1.0
# 1   Dog Food    1.0
# 2  Bird Cage    1.0
# 3  Bird Cage    1.0
# 4    Cat Toy    1.0
# 5  Bird Cage    1.0
# 6  Bird Cage    1.0
# 7   Dog Food    1.0
# 8    Cat Toy    1.0
# 9   Dog Food    1.0
# Корреляция продаж и рейтинга(сырые данные)
#    rating  sales
# 0     2.4     17
# 1     3.5     17
# 2     2.9     30
# 3     3.7     30
# 4     4.5     24
# Товары с наибольшим количеством комментариев
#           key  value
# 0   Bird Cage    999
# 1   Bird Cage    998
# 2     Cat Toy    998
# 3   Bird Cage    998
# 4   Bird Cage    996
# 5     Cat Toy    995
# 6   Bird Cage    993
# 7   Bird Cage    991
# 8     Cat Toy    989
# 9    Dog Food    983
# 10    Cat Toy    982
# 11    Cat Toy    982
# 12    Cat Toy    981
# 13  Bird Cage    980
# 14   Dog Food    979
# 15    Cat Toy    977
# 16  Bird Cage    977
# 17   Dog Food    977
# 18    Cat Toy    974
# 19  Bird Cage    974
# 20  Bird Cage    973
# 21   Dog Food    973
# 22   Dog Food    973
# 23   Dog Food    972
# 24   Dog Food    972

# %%
import json
from pprint import pprint

@spark_session
def show_inserted(spark):
    ch_url, ch_props = dbData["clickhouse"]
    for table in ["products", "sales_per_customers", "sales_per_times", "sales_per_stores", "sales_per_suppliers", "quality_of_products"
    ]:
        data_df = spark.read.jdbc(url=ch_url, table=table, properties=ch_props)
        data_df.createOrReplaceTempView(table)
        print(table)
        pprint(json.loads(spark.sql(f"select * from {table} limit 1;").first()["data"]))

show_inserted()
# Out:
# products
# {'categoryRevenue': {'Cage': 17162.96, 'Food': 15043.65, 'Toy': 17018.79},
#  'commentPerProduct': {'Bird Cage': 484.6707,
#                        'Cat Toy': 499.1497,
#                        'Dog Food': 500.45352},
#  'mostRelevantProducts': ['Bird Cage', 'Cat Toy', 'Dog Food'],
#  'ratePerProduct': {'Bird Cage': 2.9969788,
#                     'Cat Toy': 3.0866241,
#                     'Dog Food': 3.0923944}}
# sales_per_customers
# {'customerCountryStratification': {'Afghanistan': 5,
#                                    'Albania': 8,
#                                    'American Samoa': 1,
#                                    'Andorra': 1,
#                                    'Angola': 1,
#                                    'Argentina': 9,
#                                    'Armenia': 6,
#                                    'Azerbaijan': 2,
#                                    'Bangladesh': 2,
#                                    'Belarus': 2,
#                                    'Bolivia': 4,
#                                    'Bosnia and Herzegovina': 2,
#                                    'Botswana': 1,
#                                    'Brazil': 42,
#                                    'Bulgaria': 4,
#                                    'Burkina Faso': 2,
#                                    'Cameroon': 3,
#                                    'Canada': 7,
#                                    'Chile': 4,
#                                    'China': 173,
#                                    'Colombia': 13,
#                                    'Comoros': 1,
#                                    'Costa Rica': 3,
#                                    'Croatia': 3,
#                                    'Cuba': 7,
#                                    'Czech Republic': 11,
#                                    'Democratic Republic of the Congo': 2,
#                                    'Denmark': 2,
#                                    'Dominican Republic': 3,
#                                    'Ecuador': 2,
#                                    'Egypt': 6,
#                                    'Equatorial Guinea': 1,
#                                    'Eritrea': 1,
#                                    'Estonia': 1,
#                                    'Ethiopia': 1,
#                                    'Falkland Islands': 1,
#                                    'Finland': 4,
#                                    'France': 29,
#                                    'French Polynesia': 1,
#                                    'Gabon': 1,
#                                    'Georgia': 2,
#                                    'Germany': 4,
#                                    'Greece': 12,
#                                    'Guatemala': 3,
#                                    'Guinea': 2,
#                                    'Haiti': 3,
#                                    'Honduras': 13,
#                                    'Hong Kong': 1,
#                                    'Indonesia': 113,
#                                    'Iran': 5,
#                                    'Iraq': 2,
#                                    'Ireland': 3,
#                                    'Israel': 1,
#                                    'Italy': 2,
#                                    'Ivory Coast': 2,
#                                    'Jamaica': 1,
#                                    'Japan': 20,
#                                    'Kazakhstan': 5,
#                                    'Kenya': 3,
#                                    'Kyrgyzstan': 2,
#                                    'Laos': 1,
#                                    'Lebanon': 1,
#                                    'Lithuania': 1,
#                                    'Luxembourg': 2,
#                                    'Macedonia': 6,
#                                    'Madagascar': 5,
#                                    'Malawi': 3,
#                                    'Malaysia': 3,
#                                    'Mali': 2,
#                                    'Martinique': 1,
#                                    'Mauritania': 1,
#                                    'Mauritius': 2,
#                                    'Mexico': 10,
#                                    'Micronesia': 1,
#                                    'Moldova': 2,
#                                    'Mongolia': 1,
#                                    'Montenegro': 1,
#                                    'Morocco': 2,
#                                    'Nepal': 3,
#                                    'Netherlands': 4,
#                                    'New Zealand': 1,
#                                    'Nicaragua': 2,
#                                    'Niger': 1,
#                                    'Nigeria': 11,
#                                    'North Korea': 2,
#                                    'Norway': 4,
#                                    'Pakistan': 7,
#                                    'Palestinian Territory': 5,
#                                    'Panama': 1,
#                                    'Paraguay': 3,
#                                    'Peru': 6,
#                                    'Philippines': 65,
#                                    'Poland': 31,
#                                    'Portugal': 28,
#                                    'Qatar': 1,
#                                    'Russia': 74,
#                                    'Saudi Arabia': 2,
#                                    'Senegal': 1,
#                                    'Serbia': 5,
#                                    'Sierra Leone': 1,
#                                    'Slovenia': 3,
#                                    'Somalia': 2,
#                                    'South Africa': 8,
#                                    'South Korea': 1,
#                                    'Spain': 2,
#                                    'Sudan': 1,
#                                    'Swaziland': 1,
#                                    'Sweden': 24,
#                                    'Syria': 3,
#                                    'Tanzania': 6,
#                                    'Thailand': 16,
#                                    'Togo': 2,
#                                    'Tunisia': 4,
#                                    'Turkmenistan': 1,
#                                    'Uganda': 1,
#                                    'Ukraine': 8,
#                                    'United Arab Emirates': 1,
#                                    'United Kingdom': 2,
#                                    'United States': 19,
#                                    'Uzbekistan': 2,
#                                    'Venezuela': 3,
#                                    'Vietnam': 10,
#                                    'Yemen': 3,
#                                    'Zimbabwe': 3},
#  'meanOrderCostPerCustomer': {'Abba': 500.5,
#                               'Abbey': 500.5,
#                               'Abby': 500.5,
#                               'Abdel': 500.5,
#                               'Abey': 500.5,
#                               'Addy': 500.5,
#                               'Adena': 500.5,
#                               'Adiana': 500.5,
#                               'Adorne': 500.5,
#                               'Agace': 500.5,
#                               'Ailsun': 500.5,
#                               'Ainslee': 500.5,
#                               'Alaine': 500.5,
#                               'Alaster': 500.5,
#                               'Alayne': 500.5,
#                               'Alberta': 500.5,
#                               'Alec': 500.5,
#                               'Alexandros': 500.5,
#                               'Alf': 500.5,
#                               'Alfred': 500.5,
#                               'Alfredo': 500.5,
#                               'Alicea': 500.5,
#                               'Alley': 500.5,
#                               'Alleyn': 500.5,
#                               'Allison': 500.5,
#                               'Allsun': 500.5,
#                               'Allyson': 500.5,
#                               'Almeria': 500.5,
#                               'Alphonso': 500.5,
#                               'Alysa': 500.5,
#                               'Amber': 500.5,
#                               'Amelia': 500.5,
#                               'Anallise': 500.5,
#                               'Anatol': 500.5,
#                               'Andee': 500.5,
#                               'Andeee': 500.5,
#                               'Andris': 500.5,
#                               'Angel': 500.5,
#                               'Angela': 500.5,
#                               'Angelico': 500.5,
#                               'Anica': 500.5,
#                               'Anjanette': 500.5,
#                               'Annadiana': 500.5,
#                               'Annelise': 500.5,
#                               'Annnora': 500.5,
#                               'Anselm': 500.5,
#                               'Anthe': 500.5,
#                               'Antonin': 500.5,
#                               'Anya': 500.5,
#                               'April': 500.5,
#                               'Archambault': 500.5,
#                               'Archy': 500.5,
#                               'Ariadne': 500.5,
#                               'Ariana': 500.5,
#                               'Ario': 500.5,
#                               'Arlan': 500.5,
#                               'Arleen': 500.5,
#                               'Arluene': 500.5,
#                               'Armin': 500.5,
#                               'Arnuad': 500.5,
#                               'Arny': 500.5,
#                               'Aron': 500.5,
#                               'Arte': 500.5,
#                               'Arty': 500.5,
#                               'Arvie': 500.5,
#                               'Ashien': 500.5,
#                               'Ashlee': 500.5,
#                               'Auberon': 500.5,
#                               'Aubrey': 500.5,
#                               'Augie': 500.5,
#                               'Aurelie': 500.5,
#                               'Auria': 500.5,
#                               'Auroora': 500.5,
#                               'Austen': 500.5,
#                               'Ava': 500.5,
#                               'Avis': 500.5,
#                               'Aymer': 500.5,
#                               'Babbette': 500.5,
#                               'Bailie': 500.5,
#                               'Bambi': 500.5,
#                               'Ban': 500.5,
#                               'Bank': 500.5,
#                               'Barbaraanne': 500.5,
#                               'Barby': 500.5,
#                               'Barde': 500.5,
#                               'Bari': 500.5,
#                               'Barri': 500.5,
#                               'Barron': 500.5,
#                               'Bart': 500.5,
#                               'Barty': 500.5,
#                               'Basile': 500.5,
#                               'Bathsheba': 500.5,
#                               'Baxy': 500.5,
#                               'Bearnard': 500.5,
#                               'Beckie': 500.5,
#                               'Belita': 500.5,
#                               'Belvia': 500.5,
#                               'Bendicty': 500.5,
#                               'Benedicta': 500.5,
#                               'Benny': 500.5,
#                               'Benoite': 500.5,
#                               'Berenice': 500.5,
#                               'Berget': 500.5,
#                               'Bern': 500.5,
#                               'Bernelle': 500.5,
#                               'Berty': 500.5,
#                               'Bethany': 500.5,
#                               'Bette-ann': 500.5,
#                               'Billy': 500.5,
#                               'Bing': 500.5,
#                               'Bink': 500.5,
#                               'Binni': 500.5,
#                               'Blakeley': 500.5,
#                               'Bobbi': 500.5,
#                               'Bobette': 500.5,
#                               'Boigie': 500.5,
#                               'Bondie': 500.5,
#                               'Bondon': 500.5,
#                               'Brad': 500.5,
#                               'Brandais': 500.5,
#                               'Brandise': 500.5,
#                               'Brandy': 500.5,
#                               'Brena': 500.5,
#                               'Brenda': 500.5,
#                               'Brennan': 500.5,
#                               'Brit': 500.5,
#                               'Brita': 500.5,
#                               'Brittan': 500.5,
#                               'Brocky': 500.5,
#                               'Brok': 500.5,
#                               'Brose': 500.5,
#                               'Bryn': 500.5,
#                               'Buddy': 500.5,
#                               'Burl': 500.5,
#                               'Cal': 500.5,
#                               'Candace': 500.5,
#                               'Caprice': 500.5,
#                               'Cariotta': 500.5,
#                               'Carling': 500.5,
#                               'Carma': 500.5,
#                               'Carmon': 500.5,
#                               'Carolina': 500.5,
#                               'Caroljean': 500.5,
#                               'Carr': 500.5,
#                               'Casar': 500.5,
#                               'Cassandre': 500.5,
#                               'Cassandry': 500.5,
#                               'Cassi': 500.5,
#                               'Cassius': 500.5,
#                               'Catherin': 500.5,
#                               'Catherine': 500.5,
#                               'Cathrin': 500.5,
#                               'Cathyleen': 500.5,
#                               'Catrina': 500.5,
#                               'Cecilio': 500.5,
#                               'Ceil': 500.5,
#                               'Celestina': 500.5,
#                               'Celinda': 500.5,
#                               'Celka': 500.5,
#                               'Celle': 500.5,
#                               'Chad': 500.5,
#                               'Chaddy': 500.5,
#                               'Chancey': 500.5,
#                               'Charline': 500.5,
#                               'Chaunce': 500.5,
#                               'Cheri': 500.5,
#                               'Cherri': 500.5,
#                               'Ches': 500.5,
#                               'Chevy': 500.5,
#                               'Chic': 500.5,
#                               'Chilton': 500.5,
#                               'Chris': 500.5,
#                               'Christian': 500.5,
#                               'Christiana': 500.5,
#                               'Christophe': 500.5,
#                               'Christy': 500.5,
#                               'Chrotoem': 500.5,
#                               'Chrystal': 500.5,
#                               'Cicely': 500.5,
#                               'Cirilo': 500.5,
#                               'Clara': 500.5,
#                               'Clarke': 500.5,
#                               'Clem': 500.5,
#                               'Clemence': 500.5,
#                               'Clementia': 500.5,
#                               'Clementine': 500.5,
#                               'Cleo': 500.5,
#                               'Clevey': 500.5,
#                               'Codi': 500.5,
#                               'Codie': 500.5,
#                               'Cole': 500.5,
#                               'Colleen': 500.5,
#                               'Conchita': 500.5,
#                               'Conni': 500.5,
#                               'Conrade': 500.5,
#                               'Constanta': 500.5,
#                               'Consuelo': 500.5,
#                               'Corabella': 500.5,
#                               'Cordula': 500.5,
#                               'Cornie': 500.5,
#                               'Corrina': 500.5,
#                               'Corrine': 500.5,
#                               'Cort': 500.5,
#                               'Cory': 500.5,
#                               'Courtnay': 500.5,
#                               'Craig': 500.5,
#                               'Crista': 500.5,
#                               'Cristine': 500.5,
#                               'Cristy': 500.5,
#                               'Cross': 500.5,
#                               'Cymbre': 500.5,
#                               'Cynthie': 500.5,
#                               'Cyrillus': 500.5,
#                               'Dacy': 500.5,
#                               'Dagny': 500.5,
#                               'Dale': 500.5,
#                               'Dalenna': 500.5,
#                               'Dana': 500.5,
#                               'Dani': 500.5,
#                               'Danice': 500.5,
#                               'Daniela': 500.5,
#                               'Daniella': 500.5,
#                               'Danni': 500.5,
#                               'Dar': 500.5,
#                               'Dara': 500.5,
#                               'Daria': 500.5,
#                               'Darin': 500.5,
#                               'Darius': 500.5,
#                               'Darla': 500.5,
#                               'Darrick': 500.5,
#                               'Daveen': 500.5,
#                               'Davie': 500.5,
#                               'De witt': 500.5,
#                               'Debor': 500.5,
#                               'Dee': 500.5,
#                               'Deerdre': 500.5,
#                               'Del': 500.5,
#                               'Delinda': 500.5,
#                               'Dell': 500.5,
#                               'Delly': 500.5,
#                               'Demott': 500.5,
#                               'Denna': 500.5,
#                               'Dennet': 500.5,
#                               'Denni': 500.5,
#                               'Dennis': 500.5,
#                               'Dennison': 500.5,
#                               'Denver': 500.5,
#                               'Denys': 500.5,
#                               'Desiree': 500.5,
#                               'Devlen': 500.5,
#                               'Dieter': 500.5,
#                               'Dion': 500.5,
#                               'Dody': 500.5,
#                               'Dominga': 500.5,
#                               'Domingo': 500.5,
#                               'Dominik': 500.5,
#                               'Donal': 500.5,
#                               'Donalt': 500.5,
#                               'Donielle': 500.5,
#                               'Donnie': 500.5,
#                               'Donny': 500.5,
#                               'Doralynne': 500.5,
#                               'Dorene': 500.5,
#                               'Dorian': 500.5,
#                               'Doro': 500.5,
#                               'Dosi': 500.5,
#                               'Doti': 500.5,
#                               'Dru': 500.5,
#                               'Dukie': 500.5,
#                               'Dulcea': 500.5,
#                               'Dulci': 500.5,
#                               'Dulciana': 500.5,
#                               'Eadmund': 500.5,
#                               'Ebba': 500.5,
#                               'Eberhard': 500.5,
#                               'Ebony': 500.5,
#                               'Eda': 500.5,
#                               'Edee': 500.5,
#                               'Editha': 500.5,
#                               'Edsel': 500.5,
#                               'Edvard': 500.5,
#                               'Edward': 500.5,
#                               'El': 500.5,
#                               'Elaine': 500.5,
#                               'Elane': 500.5,
#                               'Eldon': 500.5,
#                               'Eleni': 500.5,
#                               'Elicia': 500.5,
#                               'Elihu': 500.5,
#                               'Elisha': 500.5,
#                               'Elissa': 500.5,
#                               'Elmira': 500.5,
#                               'Elmo': 500.5,
#                               'Elsa': 500.5,
#                               'Elsbeth': 500.5,
#                               'Elton': 500.5,
#                               'Emelen': 500.5,
#                               'Emilee': 500.5,
#                               'Emilia': 500.5,
#                               'Emiline': 500.5,
#                               'Emmanuel': 500.5,
#                               'Emmerich': 500.5,
#                               'Emmit': 500.5,
#                               'Emmye': 500.5,
#                               'Enid': 500.5,
#                               'Enoch': 500.5,
#                               'Erick': 500.5,
#                               'Erika': 500.5,
#                               'Erinn': 500.5,
#                               'Erl': 500.5,
#                               'Ermanno': 500.5,
#                               'Ernest': 500.5,
#                               'Erskine': 500.5,
#                               'Esta': 500.5,
#                               'Esteban': 500.5,
#                               'Eulalie': 500.5,
#                               'Evaleen': 500.5,
#                               'Evangelia': 500.5,
#                               'Eveleen': 500.5,
#                               'Evvie': 500.5,
#                               'Eydie': 500.5,
#                               'Ezri': 500.5,
#                               'Fancy': 500.5,
#                               'Fania': 500.5,
#                               'Fannie': 500.5,
#                               'Farah': 500.5,
#                               'Fax': 500.5,
#                               'Fayina': 500.5,
#                               'Fayth': 500.5,
#                               'Felic': 500.5,
#                               'Felicdad': 500.5,
#                               'Felipe': 500.5,
#                               'Feliza': 500.5,
#                               'Feodora': 500.5,
#                               'Ferd': 500.5,
#                               'Filia': 500.5,
#                               'Fiona': 500.5,
#                               'Flem': 500.5,
#                               'Florina': 500.5,
#                               'Fonzie': 500.5,
#                               'Forest': 500.5,
#                               'Francis': 500.5,
#                               'Francisca': 500.5,
#                               'Francoise': 500.5,
#                               'Francyne': 500.5,
#                               'Franni': 500.5,
#                               'Frasquito': 500.5,
#                               'Frazer': 500.5,
#                               'Frederica': 500.5,
#                               'Freeland': 500.5,
#                               'Freeman': 500.5,
#                               'Fremont': 500.5,
#                               'Frieda': 500.5,
#                               'Gabbie': 500.5,
#                               'Gabby': 500.5,
#                               'Gabe': 500.5,
#                               'Gabie': 500.5,
#                               'Gabrila': 500.5,
#                               'Gardy': 500.5,
#                               'Garfield': 500.5,
#                               'Garold': 500.5,
#                               'Garrick': 500.5,
#                               'Gaspar': 500.5,
#                               'Gasper': 500.5,
#                               'Gayla': 500.5,
#                               'Genia': 500.5,
#                               'Genni': 500.5,
#                               'Geoff': 500.5,
#                               'Georas': 500.5,
#                               'Geordie': 500.5,
#                               'Georgena': 500.5,
#                               'Georgianna': 500.5,
#                               'Georgianne': 500.5,
#                               'Georgine': 500.5,
#                               'Gerda': 500.5,
#                               'Gerianne': 500.5,
#                               'Germain': 500.5,
#                               'Gertie': 500.5,
#                               'Gian': 500.5,
#                               'Gianni': 500.5,
#                               'Gisele': 500.5,
#                               'Giuditta': 500.5,
#                               'Giuseppe': 500.5,
#                               'Giustina': 500.5,
#                               'Glenna': 500.5,
#                               'Goldia': 500.5,
#                               'Gonzalo': 500.5,
#                               'Goran': 500.5,
#                               'Grace': 500.5,
#                               'Gradeigh': 500.5,
#                               'Graeme': 500.5,
#                               'Gregory': 500.5,
#                               'Grier': 500.5,
#                               'Grissel': 500.5,
#                               'Guenna': 500.5,
#                               'Gunilla': 500.5,
#                               'Gweneth': 500.5,
#                               'Hadley': 500.5,
#                               'Hadrian': 500.5,
#                               'Hallie': 500.5,
#                               'Hannie': 500.5,
#                               'Hannis': 500.5,
#                               'Hansiain': 500.5,
#                               'Harlen': 500.5,
#                               'Harman': 500.5,
#                               'Haroun': 500.5,
#                               'Hatty': 500.5,
#                               'Hayes': 500.5,
#                               'Heath': 500.5,
#                               'Hedi': 500.5,
#                               'Helaine': 500.5,
#                               'Helga': 500.5,
#                               'Henderson': 500.5,
#                               'Henrie': 500.5,
#                               'Henriette': 500.5,
#                               'Henryetta': 500.5,
#                               'Herbie': 500.5,
#                               'Herschel': 500.5,
#                               'Holden': 500.5,
#                               'Holli': 500.5,
#                               'Holt': 500.5,
#                               'Ines': 500.5,
#                               'Inga': 500.5,
#                               'Ingeborg': 500.5,
#                               'Ingemar': 500.5,
#                               'Ingunna': 500.5,
#                               'Inigo': 500.5,
#                               'Inness': 500.5,
#                               'Iolande': 500.5,
#                               'Iolanthe': 500.5,
#                               'Irita': 500.5,
#                               'Irwinn': 500.5,
#                               'Isabelle': 500.5,
#                               'Isaiah': 500.5,
#                               'Iseabal': 500.5,
#                               'Isiahi': 500.5,
#                               'Issi': 500.5,
#                               'Issie': 500.5,
#                               'Jaclyn': 500.5,
#                               'Jamesy': 500.5,
#                               'Jami': 500.5,
#                               'Jamill': 500.5,
#                               'Jamima': 500.5,
#                               'Jandy': 500.5,
#                               'Janelle': 500.5,
#                               'Janette': 500.5,
#                               'Jany': 500.5,
#                               'Jarrid': 500.5,
#                               'Jayne': 500.5,
#                               'Jazmin': 500.5,
#                               'Jeana': 500.5,
#                               'Jeanine': 500.5,
#                               'Jeanne': 500.5,
#                               'Jeffie': 500.5,
#                               'Jena': 500.5,
#                               'Jenifer': 500.5,
#                               'Jennie': 500.5,
#                               'Jere': 500.5,
#                               'Jereme': 500.5,
#                               'Jermain': 500.5,
#                               'Jermaine': 500.5,
#                               'Jerrilyn': 500.5,
#                               'Jerry': 500.5,
#                               'Jessalin': 500.5,
#                               'Jessamine': 500.5,
#                               'Jesselyn': 500.5,
#                               'Jethro': 500.5,
#                               'Jill': 500.5,
#                               'Joann': 500.5,
#                               'Jobey': 500.5,
#                               'Jocelin': 500.5,
#                               'Jodee': 500.5,
#                               'Joellyn': 500.5,
#                               'Joelynn': 500.5,
#                               'Jonah': 500.5,
#                               'Jordan': 500.5,
#                               'Josephine': 500.5,
#                               'Josi': 500.5,
#                               'Juanita': 500.5,
#                               'Judas': 500.5,
#                               'Juli': 500.5,
#                               'Juliana': 500.5,
#                               'Julina': 500.5,
#                               'Julissa': 500.5,
#                               'Junia': 500.5,
#                               'Justine': 500.5,
#                               'Justis': 500.5,
#                               'Kaiser': 500.5,
#                               'Kaitlyn': 500.5,
#                               'Kaja': 500.5,
#                               'Kalil': 500.5,
#                               'Kalli': 500.5,
#                               'Kalvin': 500.5,
#                               'Karel': 500.5,
#                               'Karim': 500.5,
#                               'Karina': 500.5,
#                               'Karine': 500.5,
#                               'Karole': 500.5,
#                               'Katey': 500.5,
#                               'Katherine': 500.5,
#                               'Katinka': 500.5,
#                               'Kaycee': 500.5,
#                               'Kayla': 500.5,
#                               'Kaylee': 500.5,
#                               'Kelcie': 500.5,
#                               'Kellby': 500.5,
#                               'Kelsi': 500.5,
#                               'Kelsy': 500.5,
#                               'Kendricks': 500.5,
#                               'Kenton': 500.5,
#                               'Kerrill': 500.5,
#                               'Kessia': 500.5,
#                               'Kessiah': 500.5,
#                               'Keven': 500.5,
#                               'Kiel': 500.5,
#                               'Kimbra': 500.5,
#                               'Kip': 500.5,
#                               'Kipp': 500.5,
#                               'Kippar': 500.5,
#                               'Kira': 500.5,
#                               'Kirby': 500.5,
#                               'Kirk': 500.5,
#                               'Kittie': 500.5,
#                               'Konrad': 500.5,
#                               'Kora': 500.5,
#                               'Kort': 500.5,
#                               'Krishnah': 500.5,
#                               'Kristian': 500.5,
#                               'Kristien': 500.5,
#                               'Kristina': 500.5,
#                               'Kristos': 500.5,
#                               'Kylynn': 500.5,
#                               'Kym': 500.5,
#                               'La verne': 500.5,
#                               'Lanae': 500.5,
#                               'Land': 500.5,
#                               'Lanie': 500.5,
#                               'Lari': 500.5,
#                               'Larina': 500.5,
#                               'Larine': 500.5,
#                               'Latisha': 500.5,
#                               'Lavina': 500.5,
#                               'Layney': 500.5,
#                               'Lazare': 500.5,
#                               'Lazarus': 500.5,
#                               'Lea': 500.5,
#                               'Leann': 500.5,
#                               'Leelah': 500.5,
#                               'Leese': 500.5,
#                               'Leia': 500.5,
#                               'Leif': 500.5,
#                               'Leighton': 500.5,
#                               'Leonie': 500.5,
#                               'Leora': 500.5,
#                               'Lesly': 500.5,
#                               'Letizia': 500.5,
#                               'Lexi': 500.5,
#                               'Lianna': 500.5,
#                               'Lida': 500.5,
#                               'Lilli': 500.5,
#                               'Lin': 500.5,
#                               'Lindi': 500.5,
#                               'Linn': 500.5,
#                               'Linnet': 500.5,
#                               'Livia': 500.5,
#                               'Liza': 500.5,
#                               'Lock': 500.5,
#                               'Loella': 500.5,
#                               'Lonee': 500.5,
#                               'Lora': 500.5,
#                               'Loreen': 500.5,
#                               'Loren': 500.5,
#                               'Lorettalorna': 500.5,
#                               'Lorri': 500.5,
#                               'Lorry': 500.5,
#                               'Lotty': 500.5,
#                               'Lou': 500.5,
#                               'Louis': 500.5,
#                               'Louise': 500.5,
#                               'Lu': 500.5,
#                               'Lucille': 500.5,
#                               'Lucina': 500.5,
#                               'Lucy': 500.5,
#                               'Luke': 500.5,
#                               'Lura': 500.5,
#                               'Lydia': 500.5,
#                               'Lyn': 500.5,
#                               'Lynde': 500.5,
#                               'Lynett': 500.5,
#                               'Lyssa': 500.5,
#                               'Mable': 500.5,
#                               'Maddie': 500.5,
#                               'Madeleine': 500.5,
#                               'Madelene': 500.5,
#                               'Madella': 500.5,
#                               'Maible': 500.5,
#                               'Mandi': 500.5,
#                               'Mandie': 500.5,
#                               'Mar': 500.5,
#                               'Marcia': 500.5,
#                               'Maressa': 500.5,
#                               'Margaret': 500.5,
#                               'Margit': 500.5,
#                               'Maria': 500.5,
#                               'Marian': 500.5,
#                               'Mariann': 500.5,
#                               'Marianne': 500.5,
#                               'Maritsa': 500.5,
#                               'Marne': 500.5,
#                               'Marquita': 500.5,
#                               'Marvin': 500.5,
#                               'Marybeth': 500.5,
#                               'Maryl': 500.5,
#                               'Marylin': 500.5,
#                               'Marylou': 500.5,
#                               'Marys': 500.5,
#                               'Mathias': 500.5,
#                               'Matias': 500.5,
#                               'Mattie': 500.5,
#                               'Matty': 500.5,
#                               'Maureen': 500.5,
#                               'Maximilian': 500.5,
#                               'Maxwell': 500.5,
#                               'Megen': 500.5,
#                               'Meggy': 500.5,
#                               'Mei': 500.5,
#                               'Mel': 500.5,
#                               'Melicent': 500.5,
#                               'Melinda': 500.5,
#                               'Melli': 500.5,
#                               'Mendy': 500.5,
#                               'Mercy': 500.5,
#                               'Merell': 500.5,
#                               'Merlina': 500.5,
#                               'Merline': 500.5,
#                               'Merrill': 500.5,
#                               'Meryl': 500.5,
#                               'Mia': 500.5,
#                               'Micaela': 500.5,
#                               'Michaeline': 500.5,
#                               'Micheil': 500.5,
#                               'Michel': 500.5,
#                               'Michele': 500.5,
#                               'Micheline': 500.5,
#                               'Miguelita': 500.5,
#                               'Mildred': 500.5,
#                               'Mildrid': 500.5,
#                               'Minetta': 500.5,
#                               'Minette': 500.5,
#                               'Moishe': 500.5,
#                               'Monte': 500.5,
#                               'Moore': 500.5,
#                               'Moria': 500.5,
#                               'Morley': 500.5,
#                               'Morrie': 500.5,
#                               'Morten': 500.5,
#                               'Moses': 500.5,
#                               'Murial': 500.5,
#                               'Muriel': 500.5,
#                               'Mylo': 500.5,
#                               'Myranda': 500.5,
#                               'Myrtle': 500.5,
#                               'Nada': 500.5,
#                               'Nanette': 500.5,
#                               'Nanice': 500.5,
#                               'Nannie': 500.5,
#                               'Nara': 500.5,
#                               'Nat': 500.5,
#                               'Nathanial': 500.5,
#                               'Nathanil': 500.5,
#                               'Neala': 500.5,
#                               'Neddie': 500.5,
#                               'Nessi': 500.5,
#                               'Nettie': 500.5,
#                               'Nial': 500.5,
#                               'Nicola': 500.5,
#                               'Nicoli': 500.5,
#                               'Nicolle': 500.5,
#                               'Niels': 500.5,
#                               'Nikolai': 500.5,
#                               'Noah': 500.5,
#                               'Noami': 500.5,
#                               'Noby': 500.5,
#                               'Noelani': 500.5,
#                               'Noell': 500.5,
#                               'Nomi': 500.5,
#                               'Nonah': 500.5,
#                               'Norbert': 500.5,
#                               'Normand': 500.5,
#                               'Odelia': 500.5,
#                               'Ogden': 500.5,
#                               'Olia': 500.5,
#                               'Olivia': 500.5,
#                               'Olympia': 500.5,
#                               'Oralla': 500.5,
#                               'Orin': 500.5,
#                               'Osborne': 500.5,
#                               'Othilie': 500.5,
#                               'Paige': 500.5,
#                               'Paolo': 500.5,
#                               'Parry': 500.5,
#                               'Patrice': 500.5,
#                               'Pattie': 500.5,
#                               'Patty': 500.5,
#                               'Paul': 500.5,
#                               'Paulette': 500.5,
#                               'Pepe': 500.5,
#                               'Pet': 500.5,
#                               'Pete': 500.5,
#                               'Petronille': 500.5,
#                               'Phaedra': 500.5,
#                               'Philbert': 500.5,
#                               'Philip': 500.5,
#                               'Phillipp': 500.5,
#                               'Phillis': 500.5,
#                               'Philomena': 500.5,
#                               'Phip': 500.5,
#                               'Phoebe': 500.5,
#                               'Pia': 500.5,
#                               'Pierce': 500.5,
#                               'Piotr': 500.5,
#                               'Prent': 500.5,
#                               'Prescott': 500.5,
#                               'Prissie': 500.5,
#                               'Querida': 500.5,
#                               'Quinta': 500.5,
#                               'Rabbi': 500.5,
#                               'Rafaelia': 500.5,
#                               'Ralph': 500.5,
#                               'Ramsay': 500.5,
#                               'Randee': 500.5,
#                               'Rayna': 500.5,
#                               'Reamonn': 500.5,
#                               'Regan': 500.5,
#                               'Reta': 500.5,
#                               'Rhea': 500.5,
#                               'Rhianna': 500.5,
#                               'Riane': 500.5,
#                               'Rich': 500.5,
#                               'Richie': 500.5,
#                               'Rikki': 500.5,
#                               'Riordan': 500.5,
#                               'Roarke': 500.5,
#                               'Robbert': 500.5,
#                               'Robin': 500.5,
#                               'Robinette': 500.5,
#                               'Rochella': 500.5,
#                               'Roddy': 500.5,
#                               'Rois': 500.5,
#                               'Rolfe': 500.5,
#                               'Ronny': 500.5,
#                               'Roobbie': 500.5,
#                               'Rora': 500.5,
#                               'Rosie': 500.5,
#                               'Roth': 500.5,
#                               'Roxine': 500.5,
#                               'Rozina': 500.5,
#                               'Ruben': 500.5,
#                               'Rubi': 500.5,
#                               'Ruthie': 500.5,
#                               'Sabra': 500.5,
#                               'Saleem': 500.5,
#                               'Sander': 500.5,
#                               'Sandi': 500.5,
#                               'Sandy': 500.5,
#                               'Sara-ann': 500.5,
#                               'Saundra': 500.5,
#                               'Scarlet': 500.5,
#                               'Scot': 500.5,
#                               'Sean': 500.5,
#                               'Sebastien': 500.5,
#                               'Shae': 500.5,
#                               'Shaina': 500.5,
#                               'Shalom': 500.5,
#                               'Shandy': 500.5,
#                               'Shannan': 500.5,
#                               'Shanta': 500.5,
#                               'Sharyl': 500.5,
#                               'Shawn': 500.5,
#                               'Shayna': 500.5,
#                               'Shea': 500.5,
#                               'Sheela': 500.5,
#                               'Sheeree': 500.5,
#                               'Sheffield': 500.5,
#                               'Sherm': 500.5,
#                               'Sherwood': 500.5,
#                               'Shir': 500.5,
#                               'Shoshana': 500.5,
#                               'Sibella': 500.5,
#                               'Sibyl': 500.5,
#                               'Sidonnie': 500.5,
#                               'Sinclare': 500.5,
#                               'Sindee': 500.5,
#                               'Sisely': 500.5,
#                               'Sissy': 500.5,
#                               'Siward': 500.5,
#                               'Skipp': 500.5,
#                               'Skippie': 500.5,
#                               'Skyler': 500.5,
#                               'Sofia': 500.5,
#                               'Sofie': 500.5,
#                               'Sol': 500.5,
#                               'Solly': 500.5,
#                               'Solomon': 500.5,
#                               'Sondra': 500.5,
#                               'Sonni': 500.5,
#                               'Sonnie': 500.5,
#                               'Sonnnie': 500.5,
#                               'Sonya': 500.5,
#                               'Sophronia': 500.5,
#                               'Sorcha': 500.5,
#                               'Stacy': 500.5,
#                               'Stafani': 500.5,
#                               'Stafford': 500.5,
#                               'Stan': 500.5,
#                               'Stanford': 500.5,
#                               'Stanislaus': 500.5,
#                               'Steffie': 500.5,
#                               'Stephana': 500.5,
#                               'Stephi': 500.5,
#                               'Stevena': 500.5,
#                               'Stevy': 500.5,
#                               'Stormie': 500.5,
#                               'Suellen': 500.5,
#                               'Suki': 500.5,
#                               'Sullivan': 500.5,
#                               'Suzy': 500.5,
#                               'Svend': 500.5,
#                               'Swen': 500.5,
#                               'Sybil': 500.5,
#                               'Sybyl': 500.5,
#                               'Sylas': 500.5,
#                               'Tallie': 500.5,
#                               'Tam': 500.5,
#                               'Tate': 500.5,
#                               'Teodor': 500.5,
#                               'Teodorico': 500.5,
#                               'Tera': 500.5,
#                               'Terence': 500.5,
#                               'Tessy': 500.5,
#                               'Thaxter': 500.5,
#                               'Thekla': 500.5,
#                               'Theodora': 500.5,
#                               'Theresa': 500.5,
#                               'Therese': 500.5,
#                               'Theressa': 500.5,
#                               'Thomasine': 500.5,
#                               'Thornton': 500.5,
#                               'Tierney': 500.5,
#                               'Tiff': 500.5,
#                               'Tiffie': 500.5,
#                               'Tiffy': 500.5,
#                               'Timmie': 500.5,
#                               'Timmy': 500.5,
#                               'Tiphany': 500.5,
#                               'Tish': 500.5,
#                               'Tobias': 500.5,
#                               'Tobye': 500.5,
#                               'Tod': 500.5,
#                               'Toddie': 500.5,
#                               'Toddy': 500.5,
#                               'Tommie': 500.5,
#                               'Toni': 500.5,
#                               'Torey': 500.5,
#                               'Torie': 500.5,
#                               'Torry': 500.5,
#                               'Townsend': 500.5,
#                               'Tracey': 500.5,
#                               'Tracy': 500.5,
#                               'Trescha': 500.5,
#                               'Trey': 500.5,
#                               'Trina': 500.5,
#                               'Trisha': 500.5,
#                               'Truda': 500.5,
#                               'Tully': 500.5,
#                               'Twila': 500.5,
#                               'Twyla': 500.5,
#                               'Ulrich': 500.5,
#                               'Umeko': 500.5,
# ...
#                                    'Brazil,NW': 1,
#                                    'Brazil,NaN': 33,
#                                    'Brazil,QC': 1,
#                                    'Brazil,W': 1,
#                                    'Bulgaria,NaN': 1,
#                                    'Burundi,NaN': 1,
#                                    'Cameroon,NaN': 1,
#                                    'Canada,03': 1,
#                                    'Canada,AB': 1,
#                                    'Canada,B2': 1,
#                                    'Canada,NaN': 12,
#                                    'Central African Republic,NaN': 1,
#                                    'Chad,NaN': 1,
#                                    'Chile,NaN': 1,
#                                    'China,01': 1,
#                                    'China,03': 3,
#                                    'China,05': 1,
#                                    'China,1084': 1,
#                                    'China,13': 1,
#                                    'China,15': 3,
#                                    'China,A2': 1,
#                                    'China,A3': 1,
#                                    'China,A4': 1,
#                                    'China,A8': 2,
#                                    'China,AB': 1,
#                                    'China,AC': 1,
#                                    'China,AN': 1,
#                                    'China,B7': 1,
#                                    'China,BD': 1,
#                                    'China,BY': 1,
#                                    'China,HB': 1,
#                                    'China,I': 1,
#                                    'China,JAL': 2,
#                                    'China,MI': 1,
#                                    'China,MIC': 1,
#                                    'China,MOR': 1,
#                                    'China,NaN': 155,
#                                    'China,OAX': 1,
#                                    'China,OH': 1,
#                                    'China,ON': 1,
#                                    'China,S': 1,
#                                    'China,SRW': 1,
#                                    'China,T': 1,
#                                    'China,TN': 1,
#                                    'China,TX': 1,
#                                    'China,W': 1,
#                                    'China,WA': 1,
#                                    'China,Z': 1,
#                                    'Colombia,MEX': 1,
#                                    'Colombia,MIC': 1,
#                                    'Colombia,NaN': 11,
#                                    'Costa Rica,NaN': 1,
#                                    'Croatia,NaN': 2,
#                                    'Cuba,NaN': 4,
#                                    'Cyprus,NaN': 1,
#                                    'Czech Republic,16': 1,
#                                    'Czech Republic,A7': 1,
#                                    'Czech Republic,KUL': 1,
#                                    'Czech Republic,NaN': 16,
#                                    'Democratic Republic of the Congo,A2': 1,
#                                    'Democratic Republic of the Congo,NaN': 2,
#                                    'Djibouti,NaN': 1,
#                                    'Dominican Republic,10': 1,
#                                    'Dominican Republic,NaN': 4,
#                                    'East Timor,NaN': 1,
#                                    'Egypt,NaN': 3,
#                                    'Equatorial Guinea,NaN': 2,
#                                    'Ethiopia,NaN': 6,
#                                    'Finland,NaN': 9,
#                                    'France,03': 1,
#                                    'France,11': 1,
#                                    'France,IN': 1,
#                                    'France,LZ': 1,
#                                    'France,NaN': 30,
#                                    'France,TX': 1,
#                                    'France,Z': 1,
#                                    'Gabon,NaN': 1,
#                                    'Gambia,NaN': 1,
#                                    'Georgia,15': 1,
#                                    'Georgia,NaN': 1,
#                                    'Germany,NaN': 3,
#                                    'Ghana,NaN': 1,
#                                    'Greece,12': 1,
#                                    'Greece,B4': 1,
#                                    'Greece,B5': 1,
#                                    'Greece,CA': 1,
#                                    'Greece,NaN': 17,
#                                    'Grenada,11': 1,
#                                    'Guatemala,NaN': 2,
#                                    'Honduras,B7': 1,
#                                    'Honduras,NaN': 3,
#                                    'Hungary,NaN': 1,
#                                    'Indonesia,06': 1,
#                                    'Indonesia,07': 1,
#                                    'Indonesia,10': 1,
#                                    'Indonesia,13': 1,
#                                    'Indonesia,A2': 1,
#                                    'Indonesia,AN': 1,
#                                    'Indonesia,CM': 1,
#                                    'Indonesia,K': 1,
#                                    'Indonesia,MO': 1,
#                                    'Indonesia,NaN': 89,
#                                    'Indonesia,O': 1,
#                                    'Indonesia,ON': 1,
#                                    'Iran,B9': 1,
#                                    'Iran,NaN': 7,
#                                    'Iraq,NaN': 1,
#                                    'Ireland,NaN': 1,
#                                    'Israel,NaN': 2,
#                                    'Italy,NaN': 1,
#                                    'Ivory Coast,NaN': 2,
#                                    'Jamaica,NaN': 2,
#                                    'Japan,06': 1,
#                                    'Japan,AB': 1,
#                                    'Japan,NaN': 14,
#                                    'Jordan,NaN': 1,
#                                    'Kazakhstan,NaN': 3,
#                                    'Kenya,NaN': 4,
#                                    'Kosovo,NaN': 1,
#                                    'Kyrgyzstan,NaN': 1,
#                                    'Laos,NaN': 1,
#                                    'Latvia,NaN': 3,
#                                    'Latvia,O': 1,
#                                    'Lebanon,NaN': 1,
#                                    'Lithuania,NaN': 2,
#                                    'Luxembourg,A3': 1,
#                                    'Luxembourg,B9': 1,
#                                    'Macedonia,HE': 1,
#                                    'Macedonia,NaN': 1,
#                                    'Madagascar,K': 1,
#                                    'Madagascar,NaN': 1,
#                                    'Malaysia,NaN': 5,
#                                    'Malaysia,OAX': 1,
#                                    'Malta,NaN': 1,
#                                    'Martinique,NaN': 1,
#                                    'Mauritius,NaN': 2,
#                                    'Mexico,NaN': 4,
#                                    'Mongolia,NaN': 6,
#                                    'Morocco,18': 1,
#                                    'Morocco,NaN': 6,
#                                    'Myanmar,NaN': 1,
#                                    'Nepal,NaN': 1,
#                                    'Netherlands,NaN': 6,
#                                    'New Caledonia,NaN': 2,
#                                    'New Zealand,ENG': 1,
#                                    'Nicaragua,NaN': 1,
#                                    'Niger,NaN': 2,
#                                    'Nigeria,A8': 1,
#                                    'Nigeria,AZ': 1,
#                                    'Nigeria,NaN': 12,
#                                    'North Korea,NaN': 1,
#                                    'Norway,03': 1,
#                                    'Pakistan,NaN': 10,
#                                    'Palestinian Territory,NaN': 1,
#                                    'Panama,NaN': 1,
#                                    'Paraguay,NaN': 1,
#                                    'Peru,B4': 1,
#                                    'Peru,B7': 1,
#                                    'Peru,NaN': 10,
#                                    'Philippines,12': 2,
#                                    'Philippines,CA': 1,
#                                    'Philippines,MO': 1,
#                                    'Philippines,NaN': 35,
#                                    'Philippines,TX': 1,
#                                    'Poland,03': 1,
#                                    'Poland,07': 1,
#                                    'Poland,1084': 1,
#                                    'Poland,A7': 1,
#                                    'Poland,A8': 1,
#                                    'Poland,AB': 2,
#                                    'Poland,B8': 1,
#                                    'Poland,ENG': 1,
#                                    'Poland,NaN': 23,
#                                    'Poland,ON': 1,
#                                    'Portugal,06': 1,
#                                    'Portugal,07': 1,
#                                    'Portugal,A8': 1,
#                                    'Portugal,B9': 1,
#                                    'Portugal,NY': 1,
#                                    'Portugal,NaN': 28,
#                                    'Portugal,SGR': 1,
#                                    'Qatar,NaN': 1,
#                                    'Russia,09': 1,
#                                    'Russia,11': 1,
#                                    'Russia,31': 1,
#                                    'Russia,AB': 1,
#                                    'Russia,NB': 1,
#                                    'Russia,NaN': 43,
#                                    'Saint Vincent and the Grenadines,MQ': 1,
#                                    'Samoa,NaN': 1,
#                                    'Saudi Arabia,NaN': 1,
#                                    'Serbia,NaN': 4,
#                                    'Seychelles,NaN': 1,
#                                    'Slovenia,NaN': 1,
#                                    'South Africa,A8': 2,
#                                    'South Africa,NaN': 4,
#                                    'South Korea,NaN': 5,
#                                    'Spain,13': 1,
#                                    'Spain,NaN': 3,
#                                    'Sri Lanka,NaN': 2,
#                                    'Sudan,NaN': 1,
#                                    'Sweden,NaN': 30,
#                                    'Sweden,U': 1,
#                                    'Syria,NaN': 2,
#                                    'Syria,X': 1,
#                                    'Taiwan,NaN': 1,
#                                    'Tajikistan,NaN': 1,
#                                    'Tanzania,NaN': 6,
#                                    'Thailand,NaN': 8,
#                                    'Uganda,NaN': 3,
#                                    'Ukraine,16': 1,
#                                    'Ukraine,AB': 1,
#                                    'Ukraine,NaN': 21,
#                                    'United Kingdom,NaN': 2,
#                                    'United States,10': 1,
#                                    'United States,97': 1,
#                                    'United States,MO': 1,
#                                    'United States,NU': 1,
#                                    'United States,NaN': 26,
#                                    'United States,O': 1,
#                                    'United States,QC': 1,
#                                    'United States,Z': 1,
#                                    'Uruguay,NaN': 1,
#                                    'Uzbekistan,NaN': 3,
#                                    'Venezuela,NaN': 5,
#                                    'Vietnam,NLE': 1,
#                                    'Vietnam,NaN': 8,
#                                    'Yemen,NaN': 7,
#                                    'Yemen,SON': 1,
#                                    'Zambia,NaN': 2,
#                                    'Zimbabwe,NaN': 2}}
# sales_per_suppliers
# {'meanProductCostPerSupplier': {'Cogibox': 57.687126,
#                                 'Devpoint': 48.52,
#                                 'Digitube': 44.299065,
#                                 'Feedfire': 53.589893,
#                                 'Jaxnation': 45.040108,
#                                 'Myworks': 50.751545,
#                                 'Realpoint': 48.23404,
#                                 'Rhycero': 49.571373,
#                                 'Twimbo': 48.845867,
#                                 'Voolia': 46.60442},
#  'mostRelevantSuppliers': ['Devpoint',
#                            'Digitube',
#                            'Twimbo',
#                            'Realpoint',
#                            'Rhycero',
#                            'Myworks',
#                            'Voolia',
#                            'Jaxnation',
#                            'Cogibox',
#                            'Feedfire'],
#  'supplierSalesPerCountryDistribution': {'Brazil': 104,
#                                          'China': 303,
#                                          'Indonesia': 285,
#                                          'Japan': 104,
#                                          'Poland': 95,
#                                          'Saint Kitts and Nevis': 109}}
# quality_of_products
# {'productsHighestRate': [{'Bird Cage': 5.0},
#                          {'Dog Food': 5.0},
#                          {'Cat Toy': 5.0},
#                          {'Dog Food': 5.0},
#                          {'Dog Food': 5.0},
#                          {'Dog Food': 5.0},
#                          {'Dog Food': 5.0},
#                          {'Cat Toy': 5.0},
#                          {'Cat Toy': 5.0},
#                          {'Dog Food': 5.0}],
#  'productsLowestRate': [{'Dog Food': 1.0},
#                         {'Dog Food': 1.0},
#                         {'Bird Cage': 1.0},
#                         {'Bird Cage': 1.0},
#                         {'Cat Toy': 1.0},
#                         {'Bird Cage': 1.0},
#                         {'Bird Cage': 1.0},
#                         {'Dog Food': 1.0},
#                         {'Cat Toy': 1.0},
#                         {'Dog Food': 1.0}],
#  'productsWithBigCommentsQuantity': [{'Bird Cage': 999},
#                                      {'Bird Cage': 998},
#                                      {'Cat Toy': 998},
#                                      {'Bird Cage': 998},
#                                      {'Bird Cage': 996},
#                                      {'Cat Toy': 995},
#                                      {'Bird Cage': 993},
#                                      {'Bird Cage': 991},
#                                      {'Cat Toy': 989},
#                                      {'Dog Food': 983},
#                                      {'Cat Toy': 982},
#                                      {'Cat Toy': 982},
#                                      {'Cat Toy': 981},
#                                      {'Bird Cage': 980},
#                                      {'Dog Food': 979},
#                                      {'Cat Toy': 977},
#                                      {'Bird Cage': 977},
#                                      {'Dog Food': 977},
#                                      {'Cat Toy': 974},
#                                      {'Bird Cage': 974},
#                                      {'Bird Cage': 973},
#                                      {'Dog Food': 973},
#                                      {'Dog Food': 973},
#                                      {'Dog Food': 972},
#                                      {'Dog Food': 972}],
#  'rateAndSalesCountCorrelation': -0.14717628}
